# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\sayal\anaconda3\lib\site-packages (2.1.3)

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.1.3

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(type(arr))
print(arr)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4 5]

# %%
import numpy as np
lis= [1,2,3,4,5]
arr = np.array(lis)
print(type(arr))
print(arr)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4 5]

# %%
import numpy as np
arr=np.array(5)
print(type(arr))
print(arr)
# Out:
# <class 'numpy.ndarray'>
# 5

# %%
import numpy as np
arr = np.array([[1,2,3,4,5,],[10,20,30,40,50]])
print(arr)
# Out:
# [[ 1  2  3  4  5]
#  [10 20 30 40 50]]

# %%
import pandas as pd
mydataset = {
  'name': ["ram", "shyam", "sita"],
  'age': [3, 7, 2]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       1 import pandas as pd
#       2 mydataset = {
#       3   'name': ["ram", "shyam", "sita"],
#       4   'age': [3, 7, 2]
#       5 }
# ----> 6 myvar = pandas.DataFrame(mydataset)
#       7 print(myvar)
#
# NameError: name 'pandas' is not defined
