# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd
mydataset ={'name':["Ram","Shyam","sita"],
           'age':[3,7,2]}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     name  age
# 0    Ram    3
# 1  Shyam    7
# 2   sita    2

# %%
import pandas as pd
mydataset ={
    'name':["ram","Shyam","Sita"],
    'age':[3,7,2],
    'city':["Maha","Bang","Hyd"]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     name  age  city
# 0    ram    3  Maha
# 1  Shyam    7  Bang
# 2   Sita    2   Hyd

# %%
import pandas as pd
lis = [1,7,2]
seri = pd.Series(lis)
print(seri)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd 
import numpy as np
ser = pd.Series()
print(ser)
data = np.array(['p','y','t','h','o','n'])

ser=pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    p
# 1    y
# 2    t
# 3    h
# 4    o
# 5    n
# dtype: object

# %%
import pandas as pd
data = {
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df = pd.DataFrame(data)
print(df)
print(df["duration"])
print(df["calories"])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 0    50
# 1    40
# 2    45
# Name: duration, dtype: int64
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('C:/Users/sayal/Downloads/data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd
data = {
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
